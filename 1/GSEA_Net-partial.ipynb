# %%
import pandas as pd

# %%
import gseapy as gp
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import networkx as nx

# %%
from itertools import chain, repeat

# %%
import math

# %% [markdown]
# 1.	Realizar a análise de Enriquecimento usando o método GSEA:

# %%
down = pd.read_csv("Sup-Table-4-List_of_Down_regulated_Erosion_vs_Without-Erosion.csv")

# %%
down.head()
# Out:
#         Ensembl.ID Gene_name  log2FoldChange      padj
# 0  ENSG00000131845    ZNF304       -0.585086  0.029046
# 1  ENSG00000156502   SUPV3L1       -0.586085  0.001891
# 2  ENSG00000154781   CCDC174       -0.588956  0.008869
# 3  ENSG00000088038     CNOT3       -0.588963  0.036274
# 4  ENSG00000141367      CLTC       -0.590050  0.000862

# %%
# Podemos ver os "gene sets" que estão incluídos no gseapy. Alguns deles não estão atualizados
# Portanto, nesta tarefa vamos usar um arquivo gmt baixado do MSigDB (https://www.gsea-msigdb.org/gsea/msigdb/)
gp.get_library_name()[:10]
# Out:
# ['ARCHS4_Cell-lines',
#  'ARCHS4_IDG_Coexp',
#  'ARCHS4_Kinases_Coexp',
#  'ARCHS4_TFs_Coexp',
#  'ARCHS4_Tissues',
#  'Achilles_fitness_decrease',
#  'Achilles_fitness_increase',
#  'Aging_Perturbations_from_GEO_down',
#  'Aging_Perturbations_from_GEO_up',
#  'Allen_Brain_Atlas_10x_scRNA_2021']

# %%
down.iloc[:, 1:3]
# Out:
#      Gene_name  log2FoldChange
# 0       ZNF304       -0.585086
# 1      SUPV3L1       -0.586085
# 2      CCDC174       -0.588956
# 3        CNOT3       -0.588963
# 4         CLTC       -0.590050
# ...        ...             ...
# 1046    AHNAK2       -7.266606
# 1047     RAB3B       -7.360638
# 1048     PRRX1       -8.452209
# 1049     LARP6       -8.603596
# 1050     NALF1       -9.108437
#
# [1051 rows x 2 columns]

# %%
# Executar a análise de enriquecimento
# O Enrichr usa o Fisher exact test
#del enrichr_down

# %%
enr = gp.enrichr(gene_list=down.Gene_name,gene_sets=['gene_sets_GOBP.gmt'], outdir=None) 

#enr = gp.enrichr(gene_list=down.Gene_name,gene_sets=['Reactome_2022', "h.all.v2023.2.Hs.symbols.gmt"], outdir=None) # Para usar a versão do mesmo arquivo gmt do gseapy.get_library_name()

#resultado da análise

enrichr_down = enr.results

enrichr_down.head()
# Out:
#              Gene_set                                               Term  \
# 0  gene_sets_GOBP.gmt                   GOBP_APICAL_PROTEIN_LOCALIZATION
# 1  gene_sets_GOBP.gmt  GOBP_APOLIPOPROTEIN_A_I_MEDIATED_SIGNALING_PAT...
# 2  gene_sets_GOBP.gmt                      GOBP_APOPTOTIC_CELL_CLEARANCE
# 3  gene_sets_GOBP.gmt             GOBP_APOPTOTIC_CHROMOSOME_CONDENSATION
# 4  gene_sets_GOBP.gmt               GOBP_APOPTOTIC_MITOCHONDRIAL_CHANGES
#
#   Overlap   P-value  Adjusted P-value  Odds Ratio  Combined Score  \
# 0    2/15  0.291213          0.865932    2.410737        2.974129
# 1     1/7  0.404785          0.865932    3.001380        2.714447
# 2    3/48  0.676549          0.974958    0.998460        0.390148
# 3     1/6  0.358971          0.865932    3.547630        3.634595
# 4   5/109  0.897841          0.999951    0.679661        0.073242
#
#                              Genes
# 0                     DLG5;SHROOM3
# 1                            ABCA1
# 2                     C3;TYRO3;AXL
# 3                            TOP2A
# 4  SLC25A4;LMNA;MLLT11;CAMK2A;NOL3

# %%
enrichr_down.shape
# Out:
# (169, 8)

# %%
# somente os resultados estatisticamente significativos
enrichr_down = enrichr_down[enrichr_down["Adjusted P-value"]<0.05]

enrichr_down.reset_index(drop=True, inplace=True)
enrichr_down
# Out:
#              Gene_set                                               Term  \
# 0  gene_sets_GOBP.gmt                         GOBP_APPENDAGE_DEVELOPMENT
# 1  gene_sets_GOBP.gmt                              GOBP_AXON_DEVELOPMENT
# 2  gene_sets_GOBP.gmt                    GOBP_CELL_CELL_SIGNALING_BY_WNT
# 3  gene_sets_GOBP.gmt           GOBP_INTEGRIN_MEDIATED_SIGNALING_PATHWAY
# 4  gene_sets_GOBP.gmt                                  GOBP_OSSIFICATION
# 5  gene_sets_GOBP.gmt                    GOBP_OSTEOBLAST_DIFFERENTIATION
# 6  gene_sets_GOBP.gmt  GOBP_REGULATION_OF_CANONICAL_WNT_SIGNALING_PAT...
# 7  gene_sets_GOBP.gmt           GOBP_REGULATION_OF_WNT_SIGNALING_PATHWAY
# 8  gene_sets_GOBP.gmt                       GOBP_VASCULATURE_DEVELOPMENT
#
#   Overlap   P-value  Adjusted P-value  Odds Ratio  Combined Score  \
# 0  30/182  0.000012          0.000981    2.699048       30.670483
# 1  62/513  0.000019          0.001004    1.909859       20.718550
# 2  57/462  0.000024          0.001004    1.949077       20.752485
# 3  17/113  0.002558          0.048041    2.402710       14.340272
# 4  57/443  0.000007          0.000981    2.051237       24.447882
# 5  33/257  0.000650          0.013740    2.003750       14.703343
# 6  34/262  0.000444          0.010728    2.030478       15.672943
# 7  42/339  0.000270          0.008182    1.933147       15.886940
# 8  85/832  0.000290          0.008182    1.583941       12.899540
#
#                                                Genes
# 0  GREM1;TULP3;TBX3;ZNF219;FERMT2;CIBAR1;TBX2;OSR...
# 1  TSKU;PLPPR4;KIF5A;NFIB;ARHGEF28;OLIG2;APLP1;SE...
# 2  BICC1;TSKU;CCND1;RBMS3;NFATC4;GREM1;DACT3;FERM...
# 3  ITGA7;PRKD1;DST;FN1;FERMT2;LAMA5;ZNF304;NRP1;D...
# 4  SNAI1;HSPE1;NAB2;PRKD1;GREM1;COL5A2;FERMT2;SAT...
# 5  SNAI1;HSPE1;PRKD1;GREM1;FERMT2;SATB2;BMPR1B;CL...
# 6  BICC1;RBMS3;GREM1;DACT3;LZTS2;KANK1;COL1A1;TME...
# 7  BICC1;TSKU;RBMS3;GREM1;NFATC4;DACT3;DIXDC1;CAV...
# 8  NFATC4;C3;ROBO1;PGF;EFNB2;UNC5B;CTNNB1;CALD1;G...

# %%
enrichr_down.shape
# Out:
# (9, 8)

# %%
type(enrichr_down)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.options.mode.chained_assignment = None # disable the warning
enrichr_down.replace('GOBP_', '', regex=True, inplace=True)
enrichr_down.replace('_', ' ', regex=True, inplace=True)
enrichr_down
# Out:
#              Gene_set                                           Term Overlap  \
# 0  gene sets GOBP.gmt                          APPENDAGE DEVELOPMENT  30/182
# 1  gene sets GOBP.gmt                               AXON DEVELOPMENT  62/513
# 2  gene sets GOBP.gmt                     CELL CELL SIGNALING BY WNT  57/462
# 3  gene sets GOBP.gmt            INTEGRIN MEDIATED SIGNALING PATHWAY  17/113
# 4  gene sets GOBP.gmt                                   OSSIFICATION  57/443
# 5  gene sets GOBP.gmt                     OSTEOBLAST DIFFERENTIATION  33/257
# 6  gene sets GOBP.gmt  REGULATION OF CANONICAL WNT SIGNALING PATHWAY  34/262
# 7  gene sets GOBP.gmt            REGULATION OF WNT SIGNALING PATHWAY  42/339
# 8  gene sets GOBP.gmt                        VASCULATURE DEVELOPMENT  85/832
#
#     P-value  Adjusted P-value  Odds Ratio  Combined Score  \
# 0  0.000012          0.000981    2.699048       30.670483
# 1  0.000019          0.001004    1.909859       20.718550
# 2  0.000024          0.001004    1.949077       20.752485
# 3  0.002558          0.048041    2.402710       14.340272
# 4  0.000007          0.000981    2.051237       24.447882
# 5  0.000650          0.013740    2.003750       14.703343
# 6  0.000444          0.010728    2.030478       15.672943
# 7  0.000270          0.008182    1.933147       15.886940
# 8  0.000290          0.008182    1.583941       12.899540
#
#                                                Genes
# 0  GREM1;TULP3;TBX3;ZNF219;FERMT2;CIBAR1;TBX2;OSR...
# 1  TSKU;PLPPR4;KIF5A;NFIB;ARHGEF28;OLIG2;APLP1;SE...
# 2  BICC1;TSKU;CCND1;RBMS3;NFATC4;GREM1;DACT3;FERM...
# 3  ITGA7;PRKD1;DST;FN1;FERMT2;LAMA5;ZNF304;NRP1;D...
# 4  SNAI1;HSPE1;NAB2;PRKD1;GREM1;COL5A2;FERMT2;SAT...
# 5  SNAI1;HSPE1;PRKD1;GREM1;FERMT2;SATB2;BMPR1B;CL...
# 6  BICC1;RBMS3;GREM1;DACT3;LZTS2;KANK1;COL1A1;TME...
# 7  BICC1;TSKU;RBMS3;GREM1;NFATC4;DACT3;DIXDC1;CAV...
# 8  NFATC4;C3;ROBO1;PGF;EFNB2;UNC5B;CTNNB1;CALD1;G...

# %%
# A coluna Genes indica os genes associados com as vias
# Vamos passar essa informação para um DataFrame com duas colunas (uma via ==> um gene)

pathways = {}

# %%
for ind in enrichr_down.index:
    
    path = enrichr_down.iloc[ind, 1]
    genes = enrichr_down.loc[ind, "Genes"]

    genes = genes.strip().split(";")

    pathways[path] = genes

    #if len(genes) < 5:
        
        #break
    #else:
        #pathways[path] = genes

    df = pd.DataFrame.from_records(
        chain.from_iterable(zip(repeat(k), v) for k, v in pathways.items()),
        columns=["geneset", "genesymbol"],
    )

# %%
df.head()
# Out:
#                  geneset genesymbol
# 0  APPENDAGE DEVELOPMENT      GREM1
# 1  APPENDAGE DEVELOPMENT      TULP3
# 2  APPENDAGE DEVELOPMENT       TBX3
# 3  APPENDAGE DEVELOPMENT     ZNF219
# 4  APPENDAGE DEVELOPMENT     FERMT2

# %%
df.shape
# Out:
# (417, 2)

# %% [markdown]
# 2. rede das vias enriquecidas

# %%
G = nx.Graph() # Crear um grafo non direcionado

# %%
# adicionar nós
G.add_nodes_from(df['geneset'])

# %%
G.add_nodes_from(df['genesymbol'])

# %%
# Definir as arestas
edges = [(row['geneset'], row['genesymbol']) for index, row in df.iterrows()]

# %%
edges[:20]
# Out:
# [('APPENDAGE DEVELOPMENT', 'GREM1'),
#  ('APPENDAGE DEVELOPMENT', 'TULP3'),
#  ('APPENDAGE DEVELOPMENT', 'TBX3'),
#  ('APPENDAGE DEVELOPMENT', 'ZNF219'),
#  ('APPENDAGE DEVELOPMENT', 'FERMT2'),
#  ('APPENDAGE DEVELOPMENT', 'CIBAR1'),
#  ('APPENDAGE DEVELOPMENT', 'TBX2'),
#  ('APPENDAGE DEVELOPMENT', 'OSR2'),
#  ('APPENDAGE DEVELOPMENT', 'HOXA10'),
#  ('APPENDAGE DEVELOPMENT', 'SMOC1'),
#  ('APPENDAGE DEVELOPMENT', 'RARG'),
#  ('APPENDAGE DEVELOPMENT', 'CTNNB1'),
#  ('APPENDAGE DEVELOPMENT', 'PTCH1'),
#  ('APPENDAGE DEVELOPMENT', 'PITX1'),
#  ('APPENDAGE DEVELOPMENT', 'TWIST1'),
#  ('APPENDAGE DEVELOPMENT', 'ZNRF3'),
#  ('APPENDAGE DEVELOPMENT', 'SCX'),
#  ('APPENDAGE DEVELOPMENT', 'BMP4'),
#  ('APPENDAGE DEVELOPMENT', 'RPGRIP1L'),
#  ('APPENDAGE DEVELOPMENT', 'NOG')]

# %%
#adicionar as arestas
G.add_edges_from(edges)

# %%
import matplotlib.pyplot as plt
# definir o layout
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=300, node_color='skyblue', font_size=10, font_color='black')
# Mostrar o grafo
plt.show()

# %%
# Vamos exportar para melhor visualização no cytoscape

# %%
nx.write_gml(G, "Down_regulated_network_2.gml")
